# %%
#1
a = [1, 2, 3]
b = a
a.append(4)
b
# Out:
# [1, 2, 3, 4]

# %%
#2
class Gizmo:
    def __init__(self):
        print('Gizmo id: %d' % id(self))

x = Gizmo()
# Out:
# Gizmo id: 134069795126544

# %%
y = Gizmo() * 10
# Out:
# Gizmo id: 134069795410272
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2818280385.py in <cell line: 0>()
# ----> 1 y = Gizmo() * 10
#
# TypeError: unsupported operand type(s) for *: 'Gizmo' and 'int'

# %%
dir()
# Out:
# ['Gizmo',
#  'In',
#  'Out',
#  '_',
#  '_1',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'exit',
#  'get_ipython',
#  'quit',
#  'x']

# %%
#3
charles = {'name': 'Charles L. Dodgson', 'born': 1832}
lewis = charles
lewis is charles
# Out:
# True

# %%
id(charles), id(lewis)
# Out:
# (134069795422720, 134069795422720)

# %%
lewis['balance'] = 950
charles
# Out:
# {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}

# %%
#4
alex = {'name': 'Charles L. Dodgson', 'born': 1832, 'balance': 950}
alex == charles
# Out:
# True

# %%
alex is charles
# Out:
# False

# %%
#5
t1 = (1, 2, [30, 40])
t2 = (1, 2, [30, 40])
t1 == t2, t1 is t2
# Out:
# (True, False)

# %%
id(t1[-1])
# Out:
# 134069795467904

# %%
t1[-1].append(99)
t1, id(t1[-1])
# Out:
# ((1, 2, [30, 40, 99]), 134069795467904)

# %%
t1 == t2
# Out:
# False

# %%
#6
l1 = [3, [66, 55, 44], (7, 8, 9)]
l2 = list(l1)

l1.append(100)

l1[1].remove(55)
print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44], (7, 8, 9), 100]
# l2: [3, [66, 44], (7, 8, 9)]

# %%
l2[1] += [33, 22]

l2[2] += (10, 11)

print('l1:', l1)
print('l2:', l2)
# Out:
# l1: [3, [66, 44, 33, 22], (7, 8, 9), 100]
# l2: [3, [66, 44, 33, 22], (7, 8, 9, 10, 11)]

# %%
#7
class Bus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#8
import copy

bus1 = Bus(['Alice', 'Bill', 'Claire', 'David'])
bus2 = copy.copy(bus1)
bus3 = copy.deepcopy(bus1)

id(bus1), id(bus2), id(bus3)
# Out:
# (134069795420640, 134069795421024, 134069795421888)

# %%
bus1.drop('Bill')
bus1.passengers, bus2.passengers, bus3.passengers
# Out:
# (['Alice', 'Claire', 'David'],
#  ['Alice', 'Claire', 'David'],
#  ['Alice', 'Bill', 'Claire', 'David'])

# %%
id(bus1.passengers), id(bus2.passengers), id(bus3.passengers)
# Out:
# (134069795859200, 134069795859200, 134069795490112)

# %%
#9
a = [10,20]
b = [a,20]
a.append(b)
a
# Out:
# [10, 20, [[...], 20]]

# %%
c = copy.deepcopy(a)
c
# Out:
# [10, 20, [[...], 20]]

# %%
#10
def f(a,b):
  a += b
  return a

# %%
a = [1,2]
b = [3,4]
f(a,b),(a,b)
# Out:
# ([1, 2, 3, 4], ([1, 2, 3, 4], [3, 4]))

# %%
x = 1
y = 2
f(x,y), (x,y)
# Out:
# (3, (1, 2))

# %%
t = (10,20)
u = (30,40)
f(t,u), (t,u)
# Out:
# ((10, 20, 30, 40), ((10, 20), (30, 40)))

# %%
#예제11
class HauntedBus:
  def __init__(self, passengers=[]):
    self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#12
bus1 = HauntedBus(['Alice', 'Bill'])
bus1.passengers
# Out:
# ['Alice', 'Bill']

# %%
bus1.pick('Charlie')
bus1.drop('Alice')
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
bus2 = HauntedBus()
bus2.pick('Carrie')
bus2.passengers
# Out:
# ['Carrie']

# %%
bus3 = HauntedBus()
bus3.passengers
# Out:
# ['Carrie']

# %%
bus3.pick('Dave')
bus2.passengers
# Out:
# ['Carrie', 'Dave']

# %%
bus2.passengers is bus3.passengers
# Out:
# True

# %%
bus1.passengers
# Out:
# ['Bill', 'Charlie']

# %%
HauntedBus.__init__.__defaults__
# Out:
# (['Carrie', 'Dave'],)

# %%
HauntedBus.__init__.__defaults__[0] is bus2.passengers
# Out:
# True

# %%
#13
class TwilightBus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = passengers

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#14
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Maya', 'Diana']

# %%
#15
class TwilightBus:
  def __init__(self, passengers=None):
    if passengers is None:
      self.passengers = []
    else:
      self.passengers = list(passengers)

  def pick(self, name):
    self.passengers.append(name)

  def drop(self, name):
    self.passengers.remove(name)

# %%
#16
basketball_team = ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']
bus = TwilightBus(basketball_team)
bus.drop('Tina')
bus.drop('Pat')
basketball_team
# Out:
# ['Sue', 'Tina', 'Maya', 'Diana', 'Pat']

# %%
#17
import weakref

s1 = {1, 2, 3}
s2 = s1

def bye():
  print('Gone with the wind...')

ender = weakref.finalize(s1, bye)
ender.alive
# Out:
# True

# %%
del s1
ender.alive
# Out:
# True

# %%
s2 = 'spam'
# Out:
# Gone with the wind...

# %%
ender.alive
# Out:
# False
